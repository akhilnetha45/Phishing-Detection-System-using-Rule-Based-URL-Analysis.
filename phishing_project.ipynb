# %% [markdown]
# # Phishing Detection System using Rule-Based URL Analysis.

# %%
import requests
import whois
import socket
from datetime import datetime
from urllib.parse import urlparse
import re

RISK_THRESHOLD = 4   # Increased because we added more checks

# --- Blacklist (Sample) ---
BLACKLIST = [
    "google-secure-login.com",
    "paypal-update-account.com",
    "secure-bank-login.net"
]

# --- Checks ---

def get_domain_age(domain):
    try:
        domain_info = whois.whois(domain)
        creation_date = domain_info.creation_date

        if isinstance(creation_date, list):
            creation_date = creation_date[0]

        days_diff = (datetime.now() - creation_date).days
        print(f"[INFO] Domain Age: {days_diff} days")

        return 1 if days_diff < 180 else 0
    except:
        print("[WARNING] Could not determine domain age.")
        return 1


def check_https(url):
    try:
        response = requests.get(url, timeout=5)
        if response.url.startswith("https://"):
            print("[INFO] HTTPS: Secure")
            return 0
        else:
            print("[WARNING] HTTPS: Not Secure")
            return 1
    except:
        print("[WARNING] Cannot verify HTTPS")
        return 1


def check_url_patterns(url, parsed_url):
    risk = 0

    # IP Address
    if re.match(r"\d{1,3}(\.\d{1,3}){3}", parsed_url.netloc):
        print("[WARNING] IP address used")
        risk += 1

    # @ symbol
    if "@" in url:
        print("[WARNING] '@' symbol found")
        risk += 1

    # Too many dots
    if url.count('.') > 4:
        print("[WARNING] Too many dots")
        risk += 1

    # Sensitive words
    keywords = ['login', 'verify', 'account', 'update']
    if any(word in url.lower() for word in keywords):
        print("[WARNING] Sensitive keyword found")
        risk += 1

    return risk


def check_url_length(url):
    if len(url) > 75:
        print("[WARNING] URL too long")
        return 1
    return 0


def check_hyphen(domain):
    if "-" in domain:
        print("[WARNING] Hyphen in domain")
        return 1
    return 0


def check_dns(domain):
    try:
        socket.gethostbyname(domain)
        print("[INFO] DNS record exists")
        return 0
    except:
        print("[WARNING] No DNS record")
        return 1


def check_blacklist(domain):
    if domain in BLACKLIST:
        print("[WARNING] Domain found in blacklist")
        return 2   # higher weight
    return 0


# --- Main Function ---

def analyze_url(url):
    print("-" * 50)
    print(f"Analyzing: {url}")

    if not url.startswith(('http://', 'https://')):
        url = 'http://' + url

    parsed = urlparse(url)
    domain = parsed.netloc

    total_score = 0
    max_score = 10   # Approx total possible

    total_score += get_domain_age(domain)
    total_score += check_https(url)
    total_score += check_url_patterns(url, parsed)
    total_score += check_url_length(url)
    total_score += check_hyphen(domain)
    total_score += check_dns(domain)
    total_score += check_blacklist(domain)

    risk_percent = (total_score / max_score) * 100

    print("\nFinal Risk Score:", total_score)
    print(f"Risk Percentage: {risk_percent:.2f}%")

    if total_score >= RISK_THRESHOLD:
        print("Verdict: 🚨 PHISHING ATTEMPT")
    else:
        print("Verdict: ✅ Likely Safe")

    print("-" * 50)


# --- Example ---
if __name__ == "__main__":
    analyze_url("https://www.google.com")
    analyze_url("http://google-secure-login.com/update")
# Out:
# --------------------------------------------------
# Analyzing: https://www.google.com
# [WARNING] Could not determine domain age.
# [INFO] HTTPS: Secure
# [INFO] DNS record exists
#
# Final Risk Score: 1
# Risk Percentage: 10.00%
# Verdict: ✅ Likely Safe
# --------------------------------------------------
# --------------------------------------------------
# Analyzing: http://google-secure-login.com/update
# [WARNING] Could not determine domain age.
# [WARNING] HTTPS: Not Secure
# [WARNING] Sensitive keyword found
# [WARNING] Hyphen in domain
# [INFO] DNS record exists
# [WARNING] Domain found in blacklist
#
# Final Risk Score: 6
# Risk Percentage: 60.00%
# Verdict: 🚨 PHISHING ATTEMPT
# --------------------------------------------------
